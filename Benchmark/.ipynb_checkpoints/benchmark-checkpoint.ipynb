# %%
# %load_ext autoreload
# %autoreload 2
# %env CUDA_VISIBLE_DEVICES = 3
# Out:
# env: CUDA_VISIBLE_DEVICES=3

# %%
import pandas as pd
import torch.nn as nn

from benchmark import get_module_performance

pd.set_option("display.precision", 2)

# %%
device = 'cuda:0'
device
# Out:
# 'cuda:0'

# %%
shape = (1, 64, 128, 128)

module_collection = {'conv_64_512_1x1': nn.Conv2d(kernel_size=1, in_channels=64, out_channels=512), 
                     'conv_64_512_3x3': nn.Conv2d(kernel_size=3, in_channels=64, out_channels=512), 
                     'bottleneck_64_512_3x3': nn.Sequential(*[nn.Conv2d(kernel_size=1, in_channels=64, out_channels=32), 
                                                             nn.Conv2d(kernel_size=3, in_channels=32, out_channels=512),
                                                              ]),
                      'conv_64_512_3x3_g2': nn.Conv2d(kernel_size=7, in_channels=64, out_channels=512, groups=2),
                      'conv_64_512_3x3_g8': nn.Conv2d(kernel_size=7, in_channels=64, out_channels=512, groups=8),
                      'conv_padding': nn.Conv2d(kernel_size=3, in_channels=64, out_channels=512, padding=1),
                      'conv_nn_Padding': nn.Sequential(nn.ZeroPad2d(1),
                                                       nn.Conv2d(kernel_size=3, in_channels=64, out_channels=512))
                    }

# %%
# contiguous
module_collection_stats = pd.DataFrame(index=module_collection.keys(), 
                                       columns=['forward time mean(ms)', 'forward time std(ms)',
                                                'backward time mean(ms)', 'backward time std(ms)',
                                                'forward memory','backward memory',
                                                'macs', 'parameters', 'time total(ms)'])
        
for module_name, module_value in module_collection.items():
    module_collection_stats.loc[module_name] = get_module_performance(module_value, inputs=shape, device=device, 
                                                               track_backward=True, memory_unit='KB')

module_collection_stats
# Out:
#                       forward time mean(ms) forward time std(ms)  \
# conv_64_512_1x1                         0.4                 0.05
# conv_64_512_3x3                        0.82                 0.04
# bottleneck_64_512_3x3                   0.8                 0.04
# conv_64_512_3x3_g2                     1.97                 0.04
# conv_64_512_3x3_g8                     0.67                 0.06
# conv_padding                           0.76                 0.06
# conv_nn_Padding                        0.83                 0.03
#
#                       backward time mean(ms) backward time std(ms)  \
# conv_64_512_1x1                          0.4                  0.07
# conv_64_512_3x3                         1.28                  0.03
# bottleneck_64_512_3x3                   1.52                  0.04
# conv_64_512_3x3_g2                      2.72                  0.03
# conv_64_512_3x3_g8                      1.48                  0.04
# conv_padding                            0.96                  0.05
# conv_nn_Padding                         1.31                  0.03
#
#                       forward memory backward memory           macs  \
# conv_64_512_1x1              32994.5           128.0    545259520.0
# conv_64_512_3x3              35972.0          1152.0   4690151424.0
# bottleneck_64_512_3x3        36420.0          2624.0   2383218688.0
# conv_64_512_3x3_g2           34032.5          3136.0  11956733952.0
# conv_64_512_3x3_g8           32210.0           784.0   2994898944.0
# conv_padding                 35972.0         89216.0   4840226816.0
# conv_nn_Padding              40324.0          1152.0   4840226816.0
#
#                       parameters time total(ms)
# conv_64_512_1x1          33280.0        1397.52
# conv_64_512_3x3         295424.0         763.74
# bottleneck_64_512_3x3   150048.0         836.41
# conv_64_512_3x3_g2      803328.0        1640.38
# conv_64_512_3x3_g8      201216.0         805.37
# conv_padding            295424.0         693.92
# conv_nn_Padding         295424.0         779.51

# %%
# channels last
module_collection_stats = pd.DataFrame(index=module_collection.keys(), 
                                       columns=['forward time mean(ms)', 'forward time std(ms)',
                                                'backward time mean(ms)', 'backward time std(ms)',
                                                'forward memory','backward memory',
                                                'macs', 'parameters','time total(ms)'])
        
for module_name, module_value in module_collection.items():
    module_collection_stats.loc[module_name] = get_module_performance(module_value, inputs=shape, device=device,
                                                               track_backward=True, channels_last=True, memory_unit='MB')

module_collection_stats
# Out:
#                       forward time mean(ms) forward time std(ms)  \
# conv_64_512_1x1                        0.43                 0.04
# conv_64_512_3x3                        0.99                 0.03
# bottleneck_64_512_3x3                  0.81                 0.03
# conv_64_512_3x3_g2                     1.91                 0.04
# conv_64_512_3x3_g8                     1.09                 0.03
# conv_padding                           0.98                 0.03
# conv_nn_Padding                        1.05                 0.05
#
#                       backward time mean(ms) backward time std(ms)  \
# conv_64_512_1x1                         0.34                  0.08
# conv_64_512_3x3                         1.36                  0.04
# bottleneck_64_512_3x3                   2.24                  0.03
# conv_64_512_3x3_g2                     13.66                  0.09
# conv_64_512_3x3_g8                     12.38                  0.08
# conv_padding                            2.07                  0.04
# conv_nn_Padding                         1.41                  0.38
#
#                       forward memory backward memory           macs  \
# conv_64_512_1x1                36.47            34.0    545259520.0
# conv_64_512_3x3                37.22            34.0   4690151424.0
# bottleneck_64_512_3x3          39.65            34.0   2383218688.0
# conv_64_512_3x3_g2             37.42            39.2  11956733952.0
# conv_64_512_3x3_g8             35.64           34.77   2994898944.0
# conv_padding                   38.19            34.0   4840226816.0
# conv_nn_Padding                42.25            34.0   4840226816.0
#
#                       parameters time total(ms)
# conv_64_512_1x1          33280.0         369.95
# conv_64_512_3x3         295424.0         880.84
# bottleneck_64_512_3x3   150048.0        1161.78
# conv_64_512_3x3_g2      803328.0        5437.44
# conv_64_512_3x3_g8      201216.0        4675.73
# conv_padding            295424.0        1119.89
# conv_nn_Padding         295424.0         952.89

# %%
# amp
module_collection_stats = pd.DataFrame(index=module_collection.keys(), 
                                       columns=['forward time mean(ms)', 'forward time std(ms)',
                                                'backward time mean(ms)', 'backward time std(ms)',
                                                'forward memory','backward memory',
                                                'macs', 'parameters','time total(ms)'])
        
for module_name, module_value in module_collection.items():
    module_collection_stats.loc[module_name] = get_module_performance(module_value, inputs=shape, device=device,
                                                               track_backward=True, amp=True, memory_unit='GB')

module_collection_stats
# Out:
#                       forward time mean(ms) forward time std(ms)  \
# conv_64_512_1x1                        0.41                 0.06
# conv_64_512_3x3                        0.52                 0.06
# bottleneck_64_512_3x3                  0.68                 0.05
# conv_64_512_3x3_g2                    10.77                 0.05
# conv_64_512_3x3_g8                     2.59                 0.03
# conv_padding                           0.49                 0.03
# conv_nn_Padding                        0.58                 0.06
#
#                       backward time mean(ms) backward time std(ms)  \
# conv_64_512_1x1                         0.43                  0.11
# conv_64_512_3x3                         0.52                   0.1
# bottleneck_64_512_3x3                    1.0                  0.11
# conv_64_512_3x3_g2                     12.22                  0.04
# conv_64_512_3x3_g8                     10.27                   0.1
# conv_padding                            0.47                  0.03
# conv_nn_Padding                         0.58                   0.1
#
#                       forward memory backward memory           macs  \
# conv_64_512_1x1                 0.04            0.03    545259520.0
# conv_64_512_3x3                 0.04            0.03   4690151424.0
# bottleneck_64_512_3x3           0.04            0.03   2383218688.0
# conv_64_512_3x3_g2              0.04            0.04  11956733952.0
# conv_64_512_3x3_g8              0.03            0.03   2994898944.0
# conv_padding                    0.04            0.03   4840226816.0
# conv_nn_Padding                 0.04            0.03   4840226816.0
#
#                       parameters time total(ms)
# conv_64_512_1x1          33280.0         404.37
# conv_64_512_3x3         295424.0         460.98
# bottleneck_64_512_3x3   150048.0         716.13
# conv_64_512_3x3_g2      803328.0         7934.9
# conv_64_512_3x3_g8      201216.0        4454.41
# conv_padding            295424.0         424.63
# conv_nn_Padding         295424.0         528.16

# %%
# amp + channels last
module_collection_stats = pd.DataFrame(index=module_collection.keys(), 
                                       columns=['forward time mean(ms)', 'forward time std(ms)',
                                                'backward time mean(ms)', 'backward time std(ms)',
                                                'forward memory','backward memory',
                                                'macs', 'parameters','time total(ms)'])
        
for module_name, module_value in module_collection.items():
    module_collection_stats.loc[module_name] = get_module_performance(module_value, inputs=shape, device=device,
                                                               track_backward=True, channels_last=True, amp=True, memory_unit='B')

module_collection_stats
# Out:
#                       forward time mean(ms) forward time std(ms)  \
# conv_64_512_1x1                        0.39                 0.03
# conv_64_512_3x3                        0.49                 0.03
# bottleneck_64_512_3x3                  0.73                 0.04
# conv_64_512_3x3_g2                     10.8                 0.05
# conv_64_512_3x3_g8                     2.59                 0.03
# conv_padding                           0.53                 0.05
# conv_nn_Padding                        0.59                 0.07
#
#                       backward time mean(ms) backward time std(ms)  \
# conv_64_512_1x1                         0.36                  0.04
# conv_64_512_3x3                         0.46                  0.03
# bottleneck_64_512_3x3                   0.94                  0.11
# conv_64_512_3x3_g2                     12.24                  0.08
# conv_64_512_3x3_g8                     10.34                  0.04
# conv_padding                            0.63                  0.07
# conv_nn_Padding                         0.61                   0.1
#
#                       forward memory backward memory           macs  \
# conv_64_512_1x1           37980672.0      35654144.0    545259520.0
# conv_64_512_3x3           38805504.0      35654144.0   4690151424.0
# bottleneck_64_512_3x3     39493120.0      35654144.0   2383218688.0
# conv_64_512_3x3_g2        38068736.0      41105920.0  11956733952.0
# conv_64_512_3x3_g8        36202496.0      36454400.0   2994898944.0
# conv_padding              39845888.0      35654144.0   4840226816.0
# conv_nn_Padding           44304384.0      35654144.0   4840226816.0
#
#                       parameters time total(ms)
# conv_64_512_1x1          33280.0         357.76
# conv_64_512_3x3         295424.0         421.54
# bottleneck_64_512_3x3   150048.0         704.38
# conv_64_512_3x3_g2      803328.0        7945.56
# conv_64_512_3x3_g8      201216.0        4479.67
# conv_padding            295424.0         499.18
# conv_nn_Padding         295424.0         538.79
